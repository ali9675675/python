# %%
import builtins

# %%
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
from platform import python_version

# %%
print(python_version())
# Out:
# 3.12.3

# %%
print("\n\n\n",x,"\n",y,"\n")
print(x,y)
print(x," ",y,z)
# Out:
#  10
#  ali
#
# 10 ali
# 10   ali
# var
# ali

# %%
import xlrd
import xlwt

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

digits = load_digits()
X, y = digits.data, digits.target

means = X.mean(axis=0)

plt.figure(figsize=(17,8))
plt.plot(means, linestyle="-", marker="o", color="b")
plt.title("mean value plot")
plt.xlabel("pixel idx")
plt.ylabel("mean val")
plt.show()

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X,y = iris.data, iris.target

plt.figure(figsize=(8,6))
plt.scatter(X[:,0], X[:,1], c=y, cmap="viridis", edgecolors="k")
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.colorbar(label="species")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(X[:,0], bins=20, color="skyblue", edgecolor="black")
plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=(8,8))
ax[0,0].plot(means,color="purple")
ax[0,0].set_title("line plot")
ax[0,1].scatter(X[:,2], X[:,3], c=y, cmap="viridis")
ax[0,1].set_title("scatter plot")
ax[1,0].hist(X[:,2], bins=20, color="orange")
ax[1,0].set_title("histogram")


S_count = [len(y[y==i]) for i in range(len(np.unique(y)))]
ax[1,1].pie(S_count, labels=iris.target_names, startangle=40)
ax[1,1].set_title("pie plot")

plt.show()

# %%
import numpy as np
[len(y[y==i]) for i in range(len(np.unique(y)))]
# Out:
# [50, 50, 50]

# %% [markdown]
# ## 3D plot

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris
import numpy as np

iris = load_iris()
X,y = iris.data, iris.target

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection="3d")

plot_3d = ax.scatter(X[:,0], X[:,1], X[:,2], c=y, cmap="viridis")
ax.set_xlabel(iris.feature_names[0])
ax.set_ylabel(iris.feature_names[1])
ax.set_zlabel(iris.feature_names[2])

# rotate

el = 45 # Elevation angle
az = 45 # Azimuth angle
ax.view_init(elev=el, azim=az)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# meshgrid
x = np.linspace(-3,3,100)
y = np.linspace(-3,3,100)
x,y = np.meshgrid(x,y)
z = np.sin(np.sqrt(x**2 + y**2))

# figure and 3d axes
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection="3d")

surf = ax.plot_surface(x,y,z, cmap="viridis")
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_xlabel("x label")
ax.set_ylabel("y label")
ax.set_zlabel("z label")
ax.set_title("3d surface plot")
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import numpy as np

data= np.random.normal(size=1000)
sns.histplot(data, bins=20, kde=True, color="blue")
# Out:
# <Axes: ylabel='Count'>

# %%
x = np.random.rand(100)
y = 2 * x + np.random.normal(0,0.1,100)
sns.regplot(x=x, y=y)
# Out:
# <Axes: >

# %% [markdown]
# ## Compare with the same plot from matplotlib

# %%
from scipy import stats
x = np.random.rand(100)
y = 2 * x + np.random.normal(0,0.1,100)
plt.scatter(x,y)
slop, intercept, r_value, p_value, std_err = stats.linregress(x,y)
plt.plot(x, slop*x+intercept, color="green")
plt.show()

# %% [markdown]
# ## Pairwise Relationships with seaborn

# %%
data = sns.load_dataset("iris")
sns.pairplot(data, hue="species")

# %% [markdown]
# # scikit-image

# %% [markdown]
# ## scipy solution for image processing

# %%
import matplotlib.pyplot as plt
from skimage import io, color
image = io.imread("E:\\Picture3.jpg")
gray_image = color.rgb2gray(image)
fig, axes = plt.subplots(1,2,figsize=(10,5))
axes[0].imshow(image)
axes[0].set_title("Original")
axes[0].axis("off")
axes[1].imshow(gray_image, cmap="gray")
axes[1].set_title("altered image")
axes[1].axis("off")
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(899.5), np.float64(-0.5))

# %% [markdown]
# # Using SQLite

# %%
import sqlite3

conn = sqlite3.connect("E:\\chinook.db")
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
for table in tables:
    print(table)
# Out:
# ('albums',)
# ('sqlite_sequence',)
# ('artists',)
# ('customers',)
# ('employees',)
# ('genres',)
# ('invoices',)
# ('invoice_items',)
# ('media_types',)
# ('playlists',)
# ('playlist_track',)
# ('tracks',)
# ('sqlite_stat1',)

# %%
cursor.execute("PRAGMA table_info(employees)")
columns = cursor.fetchall()
columns
# Out:
# [(0, 'EmployeeId', 'INTEGER', 1, None, 1),
#  (1, 'LastName', 'NVARCHAR(20)', 1, None, 0),
#  (2, 'FirstName', 'NVARCHAR(20)', 1, None, 0),
#  (3, 'Title', 'NVARCHAR(30)', 0, None, 0),
#  (4, 'ReportsTo', 'INTEGER', 0, None, 0),
#  (5, 'BirthDate', 'DATETIME', 0, None, 0),
#  (6, 'HireDate', 'DATETIME', 0, None, 0),
#  (7, 'Address', 'NVARCHAR(70)', 0, None, 0),
#  (8, 'City', 'NVARCHAR(40)', 0, None, 0),
#  (9, 'State', 'NVARCHAR(40)', 0, None, 0),
#  (10, 'Country', 'NVARCHAR(40)', 0, None, 0),
#  (11, 'PostalCode', 'NVARCHAR(10)', 0, None, 0),
#  (12, 'Phone', 'NVARCHAR(24)', 0, None, 0),
#  (13, 'Fax', 'NVARCHAR(24)', 0, None, 0),
#  (14, 'Email', 'NVARCHAR(60)', 0, None, 0)]

# %%
columns_names = [col[1] for col in columns]

# %%
cursor.execute("SELECT * FROM employees ")
for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com')
# (2, 'Edwards', 'Nancy', 'Sales Manager', 1, '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com')
# (3, 'Peacock', 'Jane', 'Sales Support Agent', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com')
# (4, 'Park', 'Margaret', 'Sales Support Agent', 2, '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com')
# ...
